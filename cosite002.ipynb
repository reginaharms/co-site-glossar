# %% [markdown]
# ---
# title: "Co-Site Tags"
# jupyter: python3
# code-fold: true
# execute:
#   echo: false
#   output: asis
# ---

# %%
from datetime import datetime
import sys
import time
import requests
import html
import locale

locale.setlocale(locale.LC_ALL,"") 
#locale "de_DE" needs to be set as default on whichever system you run this notebook on
#otherwise the umlaute sorting won't work


api_url = "https://climatekg.semanticclimate.net/api.php"

def fetch_mediawiki_data(api_url, params, session):
    try:
        response = session.get(api_url, params=params)
        response.raise_for_status()  # Raise an exception for HTTP errors
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"Error fetching data from MediaWiki API: {e}")
        return None

def extract_items(data):
    items = []
    results = data.get("query", {}).get("results", {})
    
    for item_id, item_data in results.items():
        #print(item_data)
        
        
        txt_fields = ["term","vocabulary","tags","status"]
        item = {
            "id": item_id
        }

        for fieldname in txt_fields:
            if item_data["printouts"].get(fieldname, [{}]):
                #print(fieldname)
                item[fieldname] = item_data["printouts"].get(fieldname, [None])[0]
            else:
                item[fieldname] = ""
        

            #else:
            #    item[fieldname] = ""
            #    item[f"{fieldname}_links"] = ""
        

        if item["status"]:
            translate = {
                "Draft":"Entwurf",
                "Pending Review":"Review ausstehend",
                "Published":"Veröffentlicht",
                "Unpublished":"Unveröffentlicht"
            }
            for t in translate:
                if item["status"] == t:
                    item["status"] = translate[t]
        items.append(item)
    
    items_flipped = flip_tags_dictionary(items)

    return items_flipped




class Dictlist(dict):
    def __setitem__(self, key, value):
        if key not in self:
            super(Dictlist, self).__setitem__(key, [])
        self[key].append(value)


def flip_tags_dictionary(items):

    items_tags = Dictlist()

    #print(items)
    for item in items:  
        #print(f'{item["tags"]}')

        if "," in item["tags"]:
            for tag in item["tags"].split(", "):
                items_tags[tag] = f'{item["term"]}'
        else:
            items_tags[f'{item["tags"]}'] = f'{item["term"]}'
        
    return items_tags

def term_to_link(term):
    link = f"[{term.replace('/*in', ':in').replace('*in', ':in')}](https://tibhannover.github.io/co-site-glossar/cosite001.html#{term.lower().replace(' ', '-').replace('/*', '').replace('*', '')})"
    return link

def generate_html_span(items, vocabulary):
    # Sort the keys using locale.strxfrm
    sorted_dict = sorted(items.keys(), key=locale.strxfrm)
    # Return a list of tuples (key, values) in sorted order
        # Print the sorted items
    html = ''
    for key in sorted_dict:  
        html += f'''    

### <span class="gloss-term-all gloss-term">{key.replace('/*in', ':in').replace('*in', ':in')}</span> 

    '''
        terms = items[key]
        for term in terms:
            term = term_to_link(term)
            html += f'''
      
<span class="gloss-term-all gloss-tag">{term}</span><br>
           
            '''
        html += f'''     
        
---

        '''
    return html


def login(api_url, username, password):
    session = requests.Session()
    
    # Step 1: GET request to fetch login token
    login_token_params = {
        'action': 'query',
        'meta': 'tokens',
        'type': 'login',
        'format': 'json'
    }
    response = session.get(api_url, params=login_token_params)
    response.raise_for_status()
    login_token = response.json()['query']['tokens']['logintoken']
    
    # Step 2: POST request to log in
    login_params = {
        'action': 'login',
        'lgname': username,
        'lgpassword': password,
        'lgtoken': login_token,
        'format': 'json'
    }
    response = session.post(api_url, data=login_params)
    response.raise_for_status()
    login_result = response.json()
    
    if login_result['login']['result'] == 'Success':
        #print('Logged in successfully')
        return session
    else:
        print('Failed to log in')
        sys.exit(1)

def get_glossary(vocabulary, session):

    params = {
        'action': 'ask',
        'query': f'[[Item:+]] [[has subobject::+]] [[P1::Term]] [[P18::{vocabulary}]] [[P20::!Unpublished]] |?Wikibase |?P3=term |?P20=status |?P22=tags |?P18=vocabulary |sort=P3 |limit=1000',
        'format': 'json'
    }

    response = fetch_mediawiki_data(api_url, params, session)
    items = extract_items(response)
    
    if items:
        # Generate the HTML for the table
        html = '<html><head><link rel="stylesheet" href="glossary.css"></head><body>\n\n'
        html += generate_html_span(items,vocabulary)
        html += '\n</body></html>'
        print(html)

# %%
username = 'reader'  # Replace with your username
password = 'readonly'  # Replace with your password

session = login(api_url, username, password)
get_glossary("CoSite", session)
# Out:
# <html><head><link rel="stylesheet" href="glossary.css"></head><body>
#
#
#
# ### <span class="gloss-term-all gloss-term">CoSite</span>
#
#
#
# <span class="gloss-term-all gloss-tag">[Datenvisualisierung](https://tibhannover.github.io/co-site-glossar/cosite001.html#datenvisualisierung)</span><br>
#
#
#
# ---
#
#
#
# ### <span class="gloss-term-all gloss-term">Daten</span>
#
#
#
# <span class="gloss-term-all gloss-tag">[Dateninteroperabilität](https://tibhannover.github.io/co-site-glossar/cosite001.html#dateninteroperabilität)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Datenkatalog](https://tibhannover.github.io/co-site-glossar/cosite001.html#datenkatalog)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Fernerkundung](https://tibhannover.github.io/co-site-glossar/cosite001.html#fernerkundung)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Fühlbarer Wärmestrom](https://tibhannover.github.io/co-site-glossar/cosite001.html#fühlbarer-wärmestrom)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Geodaten](https://tibhannover.github.io/co-site-glossar/cosite001.html#geodaten)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Metadaten](https://tibhannover.github.io/co-site-glossar/cosite001.html#metadaten)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Räumliche Auflösung](https://tibhannover.github.io/co-site-glossar/cosite001.html#räumliche-auflösung)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Zeitliche Auflösung](https://tibhannover.github.io/co-site-glossar/cosite001.html#zeitliche-auflösung)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Zeitreihe](https://tibhannover.github.io/co-site-glossar/cosite001.html#zeitreihe)</span><br>
#
#
#
# ---
#
#
#
# ### <span class="gloss-term-all gloss-term">Digitale Technologien</span>
#
#
#
# <span class="gloss-term-all gloss-tag">[Controller](https://tibhannover.github.io/co-site-glossar/cosite001.html#controller)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Digitaler Zwilling](https://tibhannover.github.io/co-site-glossar/cosite001.html#digitaler-zwilling)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Eye-Tracking](https://tibhannover.github.io/co-site-glossar/cosite001.html#eye-tracking)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Game-Based Learning](https://tibhannover.github.io/co-site-glossar/cosite001.html#game-based-learning)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Gamification](https://tibhannover.github.io/co-site-glossar/cosite001.html#gamification)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Hand-Tracking](https://tibhannover.github.io/co-site-glossar/cosite001.html#hand-tracking)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Urbaner Digitaler Zwilling](https://tibhannover.github.io/co-site-glossar/cosite001.html#urbaner-digitaler-zwilling)</span><br>
#
#
#
# ---
#
#
#
# ### <span class="gloss-term-all gloss-term">GBI</span>
#
#
#
# <span class="gloss-term-all gloss-tag">[Blau-grüne Infrastruktur](https://tibhannover.github.io/co-site-glossar/cosite001.html#blau-grüne-infrastruktur)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Blaue Infrastruktur](https://tibhannover.github.io/co-site-glossar/cosite001.html#blaue-infrastruktur)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Dachbegrünung](https://tibhannover.github.io/co-site-glossar/cosite001.html#dachbegrünung)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Dezentrale Regenwasserversickerung](https://tibhannover.github.io/co-site-glossar/cosite001.html#dezentrale-regenwasserversickerung)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Dürre](https://tibhannover.github.io/co-site-glossar/cosite001.html#dürre)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Entsiegelung](https://tibhannover.github.io/co-site-glossar/cosite001.html#entsiegelung)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Fassadenbegrünung](https://tibhannover.github.io/co-site-glossar/cosite001.html#fassadenbegrünung)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Grün-blaue Infrastruktur](https://tibhannover.github.io/co-site-glossar/cosite001.html#grün-blaue-infrastruktur)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[Grüne Infrastruktur](https://tibhannover.github.io/co-site-glossar/cosite001.html#grüne-infrastruktur)</span><br>
#
#
#
# <span class="gloss-term-all gloss-tag">[